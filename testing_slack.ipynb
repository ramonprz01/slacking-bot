# %%
import slack
import os
import requests
from pprint import pprint

# %%
slack_token = "Token"
client = slack.WebClient(slack_token)

client.conversations_info(
  channel="general",
  include_num_members = True
)

# %%
sapi = requests.get("https://slack.com/api/conversations.list?token=xoxb-191752512519-1023784451127-zJ3isLehjCUcJsa8rYbaBUA0")

# %% [markdown]
# "id":"C5LAM6JPK"

# %%
pprint(sapi.text)
# Out:
# ('{"ok":true,"channels":[{"id":"C5LAM6JPK","name":"general","is_channel":true,"is_group":false,"is_im":false,"created":1496285480,"is_archived":false,"is_general":true,"unlinked":0,"name_normalized":"general","is_shared":false,"parent_conversation":null,"creator":"U5M0PJWSH","is_ext_shared":false,"is_org_shared":false,"shared_team_ids":["T5MN4F2F9"],"pending_shared":[],"pending_connected_team_ids":[],"is_pending_ext_shared":false,"is_member":true,"is_private":false,"is_mpim":false,"topic":{"value":"Company-wide '
#  'announcements and work-based '
#  'matters","creator":"","last_set":0},"purpose":{"value":"This channel is for '
#  'team-wide communication and announcements. All team members are in this '
# ...

# %%
import json
y = json.loads(sapi.text)

# %%
pprint(y)
# Out:
# {'channels': [{'created': 1496285480,
#                'creator': 'U5M0PJWSH',
#                'id': 'C5LAM6JPK',
#                'is_archived': False,
#                'is_channel': True,
#                'is_ext_shared': False,
#                'is_general': True,
#                'is_group': False,
#                'is_im': False,
#                'is_member': True,
#                'is_mpim': False,
#                'is_org_shared': False,
#                'is_pending_ext_shared': False,
#                'is_private': False,
#                'is_shared': False,
#                'name': 'general',
#                'name_normalized': 'general',
#                'num_members': 53,
#                'parent_conversation': None,
#                'pending_connected_team_ids': [],
#                'pending_shared': [],
#                'previous_names': [],
#                'purpose': {'creator': '',
#                            'last_set': 0,
# ...

# %%
pprint(y['channels'][0]['name_normalized'])
# Out:
# 'general'

# %%
len(sapi.text)
# Out:
# 30100

# %%
chan_api = requests.get("https://slack.com/api/conversations.history?token=xoxb-191752512519-1023784451127-zJ3isLehjCUcJsa8rYbaBUA0&channel=C5LAM6JPK")

# %%
pprint(chan_api.text)
# Out:
# ('{"ok":true,"messages":[{"client_msg_id":"75C2AC8B-EB09-43FF-B780-D4276FDF58B4","type":"message","text":"<!channel> '
#  'I was thinking last night re announcements of virtual meetups \\/ workshops '
#  'and other virtual events, would it be okay if I post them in either Ed or '
#  'Canvas? I\\u2019m happy to do this every week too.\\nI\\u2019m seeing so '
#  'many virtual meetups and workshops popup, and I think it would be amazing to '
#  'get the word out there for our future developers and to see what the tech '
#  'community is all about: thriving, exciting and supportive! '
#  ':raised_hands:\\nI use to do this every week for Brisbane when advertising '
#  'F2F events, and now that these events are going virtual, any one can attend '
#  'no matter where you are.\\nHappy to hear your thoughts '
# ...

# %%
channel_info = json.loads(chan_api.text)

# %%
channel_info['messages']
# Out:
# [{'client_msg_id': '75C2AC8B-EB09-43FF-B780-D4276FDF58B4',
#   'type': 'message',
#   'text': '<!channel> I was thinking last night re announcements of virtual meetups / workshops and other virtual events, would it be okay if I post them in either Ed or Canvas? I’m happy to do this every week too.\nI’m seeing so many virtual meetups and workshops popup, and I think it would be amazing to get the word out there for our future developers and to see what the tech community is all about: thriving, exciting and supportive! :raised_hands:\nI use to do this every week for Brisbane when advertising F2F events, and now that these events are going virtual, any one can attend no matter where you are.\nHappy to hear your thoughts :slightly_smiling_face:',
#   'user': 'U9N4WJJFR',
#   'ts': '1585083822.099500',
#   'team': 'T5MN4F2F9',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zoF6A',
#     'elements': [{'type': 'rich_text_section',
# ...

# %%
channel_info['response_metadata']
# Out:
# {'ok': True,
#  'messages': [{'client_msg_id': '75C2AC8B-EB09-43FF-B780-D4276FDF58B4',
#    'type': 'message',
#    'text': '<!channel> I was thinking last night re announcements of virtual meetups / workshops and other virtual events, would it be okay if I post them in either Ed or Canvas? I’m happy to do this every week too.\nI’m seeing so many virtual meetups and workshops popup, and I think it would be amazing to get the word out there for our future developers and to see what the tech community is all about: thriving, exciting and supportive! :raised_hands:\nI use to do this every week for Brisbane when advertising F2F events, and now that these events are going virtual, any one can attend no matter where you are.\nHappy to hear your thoughts :slightly_smiling_face:',
#    'user': 'U9N4WJJFR',
#    'ts': '1585083822.099500',
#    'team': 'T5MN4F2F9',
#    'blocks': [{'type': 'rich_text',
#      'block_id': 'zoF6A',
#      'elements': [{'type': 'rich_text_section',
# ...

# %%
channel_info['response_metadata']['next_cursor']
# Out:
# 'bmV4dF90czoxNTg0Njg1MDM3Mzg1NzAw'

# %%
another_api = requests.get("https://slack.com/api/conversations.history\
  # ?token=xoxb-191752512519-1023784451127-zJ3isLehjCUcJsa8rYbaBUA0\
  &channel=C5LAM6JPK\
  &latest=1585083822.099500\
  &limit=1\
  &inclusive=true")

# %%
pprint(another_api.text)
# Out:
# '{"ok":false,"error":"invalid_auth"}'
